# %%
import torch

# %%
## Image 4
## b c h w
## tensor : 4 dimension
## h w , channel

# %%
x = torch.tensor([[[1,2,3]]],dtype=torch.float32)
## torch.Tensor() ## class
## It's a class

# %%
x.dtype
# Out:
# torch.float32

# %%
x.shape
# Out:
# torch.Size([1, 1, 3])

# %%
x.dim()
# Out:
# 3

# %%
## Einstein operations
## Interesting -> powerful

# %%
1 + 2+ 3 + 4 ...+ 100
100+99+97 + ....+ 1
101 101 101 101 ... 101

n*(n+1)/2

# %%
def f(n):
    return n*(n+1)/2

f(10) ## analytical solution - closed form - strapnov generic programming
# Out:
# 55.0

# %%
def g(n):
    sums = 0.0
    for i in range(1, n+1):
        sums +=i
    return sums ## iterative solution

# %%
g(10)
# Out:
# 55.0

# %%
## lbfgs
## IRLS : Iterative reweighted Least squares
## OLS -> sigmoid garbage

# %%
## pytorch  training loop (training loop logistic regression -> )
from sklearn.linear_models import LogisticRegression
l = LogisticRegression()
l.fit(x,y)

# %%
transform_matrix( torch.tensor([[1,2],[3,4]], dtype=torch.float), torch.eye(2), torch.eye(2) )
# Out:
# torch.float32 torch.float32
# torch.float32
# tensor([[1., 2.],
#         [3., 4.]])
